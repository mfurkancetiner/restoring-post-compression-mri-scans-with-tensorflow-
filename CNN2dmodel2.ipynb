# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import activations
from tensorflow.keras.layers import (Conv2D, Dense, Concatenate, Add, ReLU, Input, GlobalAveragePooling2D, Activation,
                                     Conv1D, Multiply, Permute)
from tensorflow.keras import optimizers
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from matplotlib import pyplot as plt
from keras.callbacks import CSVLogger
from collections import deque
import gc
import copy


config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)


root = os.getcwd()

# %%
path_post_enc = "C:\\Users\\Furkan\\Desktop\\BLG4901E\\nii_deney\\post_enc_frames"
path_pre_enc = "C:\\Users\\Furkan\\Desktop\\BLG4901E\\nii_deney\\pre_enc_frames"
batch_size = 10


def data_generator(start_index, batch_size=batch_size):
    X = []
    y = []
    for i in range(start_index, start_index + batch_size):
        folders = os.listdir(path_post_enc)
        os.chdir(os.path.join(path_post_enc, folders[i]))
        files = os.listdir(os.getcwd())
        for file in files:
            with open(file, 'rb') as yuv_file:
                X.append(np.frombuffer(yuv_file.read(256 * 256), dtype=np.uint8).reshape((256, 256, 1)))

    for i in range(start_index, start_index + batch_size):
        folders = os.listdir(path_pre_enc)
        os.chdir(os.path.join(path_pre_enc, folders[i]))
        files = os.listdir(os.getcwd())
        for file in files:
            with open(file, 'rb') as yuv_file:
                y.append(np.frombuffer(yuv_file.read(256 * 256), dtype=np.uint8).reshape((256, 256, 1)))

    X = np.array(X) / 255.0
    y = np.array(y) / 255.0

    return X, y, start_index + batch_size

# %%
def dc_block(input):
    x = Conv2D(filters=8, kernel_size=3, strides=1, padding='same')(input)

    x1 = Dense(12, activation='relu')(x)
    x1 = Conv2D(filters=12, kernel_size=3, strides=1,
                padding='same', activation='relu')(x1)

    x2 = Dense(16, activation='relu')(x1)
    x2 = Dense(16, activation='relu')(x2)
    x2 = Conv2D(filters=16, kernel_size=3, strides=1,
                padding='same', activation='relu')(x2)

    x3 = Dense(20, activation='relu')(x2)
    x3 = Dense(20, activation='relu')(x3)
    x3 = Dense(20, activation='relu')(x3)
    x3 = Conv2D(filters=20, kernel_size=3, strides=1,
                padding='same', activation='relu')(x3)

    x4 = Dense(24, activation='relu')(x3)
    x4 = Dense(24, activation='relu')(x4)
    x4 = Dense(24, activation='relu')(x4)
    x4 = Dense(24, activation='relu')(x4)
    x4 = Conv2D(filters=24, kernel_size=3, strides=1,
                padding='same', activation='relu')(x4)

    x5 = Dense(24, activation='relu')(x4)
    x5 = Concatenate()([Dense(8)(input), x5])
    x5 = Conv2D(filters=16, kernel_size=3, strides=1,
                padding='same', activation='relu')(x5)

    x6 = Add()([x5, input])
    out = Conv2D(filters=16, kernel_size=3, strides=1,
                 padding='same', activation='relu')(x6)

    return out


def dcr_net(input_shape=(None, None, 1), filters=16,
            name='DCRN_model'):  # ORIGINAL 64 filters!!!
    lr_image = Input(shape=input_shape, name='input')
    x_start = Conv2D(filters, kernel_size=3, strides=1,
                     padding='same')(lr_image)
    x_start = ReLU()(x_start)
    x = dc_block(x_start)
    x1 = dc_block(x)
    x2 = dc_block(x1)
    x3 = Concatenate()([Dense(16)(x_start), x, x1, x2])
    x4 = Conv2D(filters, kernel_size=3, strides=1, padding='same')(x3)
    x4 = ReLU()(x4)
    # x5 = cab(x4)
    x5 = Add()([x4, x_start])
    out = Conv2D(1, kernel_size=3, strides=1, padding='same',
                 dtype='float64')(x5)
    return tf.keras.Model(inputs=lr_image, outputs=out, name=name)


def cab(input):
    x = GlobalAveragePooling2D()(input)
    x = Permute((2, 1))(x)  # Act on channel axis
    x = Conv1D()(x)
    x = ReLU()(x)
    x = Conv1D()(x)
    x = Activation('sigma')(x)
    x = Permute((2, 1))(x)  # Restore original channel axis
    out = Multiply()([x, input])
    return out

# %%
Model = dcr_net()

# %%
csv_logger = CSVLogger('C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\log.csv', append=True, separator=';')

# %%
checkpoint_filepath = 'C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\chkpt\\model_checkpoint.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='loss',
    mode='max',
    save_best_only=False,
    save_weights_only=False,
    save_freq="epoch")

# %%
Model = tf.keras.models.load_model(checkpoint_filepath) # ÇOK DİKKAT ET BU KAPALI BUNUN KAPALI OLMASI GERKEN DURUMLAR OLABİLİR

# %%
optimizer = optimizers.Adam(learning_rate=1e-4)
Model.compile(optimizer=optimizer, loss='mse', metrics=["mse", "mae"])
Model.summary()
# Out:
# Model: "DCRN_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, None, None,  0           []
#                                  1)]
#
#  conv2d (Conv2D)                (None, None, None,   160         ['input[0][0]']
#                                 16)
#
#  re_lu (ReLU)                   (None, None, None,   0           ['conv2d[0][0]']
#                                 16)
#
#  conv2d_1 (Conv2D)              (None, None, None,   1160        ['re_lu[0][0]']
#                                 8)
#
#  dense (Dense)                  (None, None, None,   108         ['conv2d_1[0][0]']
#                                 12)
#
#  conv2d_2 (Conv2D)              (None, None, None,   1308        ['dense[0][0]']
#                                 12)
#
#  dense_1 (Dense)                (None, None, None,   208         ['conv2d_2[0][0]']
#                                 16)
#
#  dense_2 (Dense)                (None, None, None,   272         ['dense_1[0][0]']
#                                 16)
#
#  conv2d_3 (Conv2D)              (None, None, None,   2320        ['dense_2[0][0]']
#                                 16)
#
#  dense_3 (Dense)                (None, None, None,   340         ['conv2d_3[0][0]']
#                                 20)
#
#  dense_4 (Dense)                (None, None, None,   420         ['dense_3[0][0]']
#                                 20)
#
#  dense_5 (Dense)                (None, None, None,   420         ['dense_4[0][0]']
#                                 20)
#
#  conv2d_4 (Conv2D)              (None, None, None,   3620        ['dense_5[0][0]']
#                                 20)
#
#  dense_6 (Dense)                (None, None, None,   504         ['conv2d_4[0][0]']
#                                 24)
#
#  dense_7 (Dense)                (None, None, None,   600         ['dense_6[0][0]']
#                                 24)
#
#  dense_8 (Dense)                (None, None, None,   600         ['dense_7[0][0]']
#                                 24)
#
#  dense_9 (Dense)                (None, None, None,   600         ['dense_8[0][0]']
#                                 24)
#
#  conv2d_5 (Conv2D)              (None, None, None,   5208        ['dense_9[0][0]']
#                                 24)
#
#  dense_11 (Dense)               (None, None, None,   136         ['re_lu[0][0]']
#                                 8)
#
#  dense_10 (Dense)               (None, None, None,   600         ['conv2d_5[0][0]']
#                                 24)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['dense_11[0][0]',
#                                 32)                               'dense_10[0][0]']
#
#  conv2d_6 (Conv2D)              (None, None, None,   4624        ['concatenate[0][0]']
#                                 16)
#
#  add (Add)                      (None, None, None,   0           ['conv2d_6[0][0]',
#                                 16)                               're_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, None, None,   2320        ['add[0][0]']
#                                 16)
#
#  conv2d_8 (Conv2D)              (None, None, None,   1160        ['conv2d_7[0][0]']
#                                 8)
#
#  dense_12 (Dense)               (None, None, None,   108         ['conv2d_8[0][0]']
#                                 12)
#
#  conv2d_9 (Conv2D)              (None, None, None,   1308        ['dense_12[0][0]']
#                                 12)
#
#  dense_13 (Dense)               (None, None, None,   208         ['conv2d_9[0][0]']
#                                 16)
#
#  dense_14 (Dense)               (None, None, None,   272         ['dense_13[0][0]']
#                                 16)
#
#  conv2d_10 (Conv2D)             (None, None, None,   2320        ['dense_14[0][0]']
#                                 16)
#
#  dense_15 (Dense)               (None, None, None,   340         ['conv2d_10[0][0]']
#                                 20)
#
#  dense_16 (Dense)               (None, None, None,   420         ['dense_15[0][0]']
#                                 20)
#
#  dense_17 (Dense)               (None, None, None,   420         ['dense_16[0][0]']
#                                 20)
#
#  conv2d_11 (Conv2D)             (None, None, None,   3620        ['dense_17[0][0]']
#                                 20)
#
#  dense_18 (Dense)               (None, None, None,   504         ['conv2d_11[0][0]']
#                                 24)
#
#  dense_19 (Dense)               (None, None, None,   600         ['dense_18[0][0]']
#                                 24)
#
#  dense_20 (Dense)               (None, None, None,   600         ['dense_19[0][0]']
#                                 24)
#
#  dense_21 (Dense)               (None, None, None,   600         ['dense_20[0][0]']
#                                 24)
#
#  conv2d_12 (Conv2D)             (None, None, None,   5208        ['dense_21[0][0]']
#                                 24)
#
#  dense_23 (Dense)               (None, None, None,   136         ['conv2d_7[0][0]']
#                                 8)
#
#  dense_22 (Dense)               (None, None, None,   600         ['conv2d_12[0][0]']
#                                 24)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['dense_23[0][0]',
#                                 32)                               'dense_22[0][0]']
#
#  conv2d_13 (Conv2D)             (None, None, None,   4624        ['concatenate_1[0][0]']
#                                 16)
#
#  add_1 (Add)                    (None, None, None,   0           ['conv2d_13[0][0]',
#                                 16)                               'conv2d_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, None, None,   2320        ['add_1[0][0]']
#                                 16)
#
#  conv2d_15 (Conv2D)             (None, None, None,   1160        ['conv2d_14[0][0]']
#                                 8)
#
#  dense_24 (Dense)               (None, None, None,   108         ['conv2d_15[0][0]']
#                                 12)
#
#  conv2d_16 (Conv2D)             (None, None, None,   1308        ['dense_24[0][0]']
#                                 12)
#
#  dense_25 (Dense)               (None, None, None,   208         ['conv2d_16[0][0]']
#                                 16)
#
#  dense_26 (Dense)               (None, None, None,   272         ['dense_25[0][0]']
#                                 16)
#
#  conv2d_17 (Conv2D)             (None, None, None,   2320        ['dense_26[0][0]']
#                                 16)
#
#  dense_27 (Dense)               (None, None, None,   340         ['conv2d_17[0][0]']
#                                 20)
#
#  dense_28 (Dense)               (None, None, None,   420         ['dense_27[0][0]']
#                                 20)
#
#  dense_29 (Dense)               (None, None, None,   420         ['dense_28[0][0]']
#                                 20)
#
#  conv2d_18 (Conv2D)             (None, None, None,   3620        ['dense_29[0][0]']
#                                 20)
#
#  dense_30 (Dense)               (None, None, None,   504         ['conv2d_18[0][0]']
#                                 24)
#
#  dense_31 (Dense)               (None, None, None,   600         ['dense_30[0][0]']
#                                 24)
#
#  dense_32 (Dense)               (None, None, None,   600         ['dense_31[0][0]']
#                                 24)
#
#  dense_33 (Dense)               (None, None, None,   600         ['dense_32[0][0]']
#                                 24)
#
#  conv2d_19 (Conv2D)             (None, None, None,   5208        ['dense_33[0][0]']
#                                 24)
#
#  dense_35 (Dense)               (None, None, None,   136         ['conv2d_14[0][0]']
#                                 8)
#
#  dense_34 (Dense)               (None, None, None,   600         ['conv2d_19[0][0]']
#                                 24)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['dense_35[0][0]',
#                                 32)                               'dense_34[0][0]']
#
#  conv2d_20 (Conv2D)             (None, None, None,   4624        ['concatenate_2[0][0]']
#                                 16)
#
#  add_2 (Add)                    (None, None, None,   0           ['conv2d_20[0][0]',
#                                 16)                               'conv2d_14[0][0]']
#
#  dense_36 (Dense)               (None, None, None,   272         ['re_lu[0][0]']
#                                 16)
#
#  conv2d_21 (Conv2D)             (None, None, None,   2320        ['add_2[0][0]']
#                                 16)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['dense_36[0][0]',
#                                 64)                               'conv2d_7[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   9232        ['concatenate_3[0][0]']
#                                 16)
#
#  re_lu_1 (ReLU)                 (None, None, None,   0           ['conv2d_22[0][0]']
#                                 16)
#
#  add_3 (Add)                    (None, None, None,   0           ['re_lu_1[0][0]',
#                                 16)                               're_lu[0][0]']
#
#  conv2d_23 (Conv2D)             (None, None, None,   145         ['add_3[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 85,913
# Trainable params: 85,913
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# epochs = 460 (0.8 test size)
st_ix = 0
epochs = 10
file_path = 'C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\devam_indisi.txt'
kac_epoch = 'C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\d_kac_epoch.txt'

for i in range(3):
    while True:
        with open(file_path, 'r') as file:
            st_ix = int(file.read())
        
        if st_ix >= 464:
            with open(file_path, 'w') as file:
                file.write("0")
            with open(kac_epoch, 'r') as file:
                a = file.read()
                a = int(a)
            with open(kac_epoch, 'w') as file:
                a += 1
                file.write(f"{a}")
            break

        X_train, y_train, st_ix = data_generator(st_ix, 8)

        Model.fit(
            x=X_train,
            y=y_train,
            epochs=1,
            batch_size=4,
            shuffle=True,
            callbacks=[model_checkpoint_callback]
        )

        with open(file_path, 'w') as file:
            file.write(f"{st_ix}")

        gc.collect()
# Out:
# 221/221 [==============================] - 43s 193ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0186
# 253/253 [==============================] - 49s 195ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0184
# 257/257 [==============================] - 51s 196ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0174
# 258/258 [==============================] - 51s 197ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0177
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0183
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0178
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0184
# 260/260 [==============================] - 47s 179ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0169
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0170
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0181
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0181
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0176
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0170
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0172
# 260/260 [==============================] - 45s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0181
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0173
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0172
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0168
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0184
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0182
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0181
# 260/260 [==============================] - 45s 175ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0171
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0188
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0172
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0164
# 269/269 [==============================] - 47s 175ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0156
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0167
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0170
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0172
# 260/260 [==============================] - 46s 176ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0165
# 260/260 [==============================] - 46s 175ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0170
# 266/266 [==============================] - 47s 175ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0167
# 262/262 [==============================] - 50s 191ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0169
# 268/268 [==============================] - 52s 195ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0167
# 263/263 [==============================] - 47s 180ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0177
# 262/262 [==============================] - 52s 197ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0173
# 265/265 [==============================] - 52s 197ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0168
# 266/266 [==============================] - 48s 180ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0171
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0173
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0167
# 265/265 [==============================] - 53s 197ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0166
# 263/263 [==============================] - 48s 181ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0159
# 262/262 [==============================] - 52s 197ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0170
# 262/262 [==============================] - 52s 197ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0169
# 260/260 [==============================] - 47s 181ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0175
# 260/260 [==============================] - 47s 181ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0164
# 265/265 [==============================] - 52s 196ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0169
# 266/266 [==============================] - 48s 180ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0156
# 263/263 [==============================] - 48s 180ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0161
# 262/262 [==============================] - 52s 196ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0169
# 260/260 [==============================] - 47s 179ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0176
# 265/265 [==============================] - 52s 196ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0162
# 269/269 [==============================] - 48s 178ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0160
# 263/263 [==============================] - 47s 179ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0163
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0170
# 260/260 [==============================] - 47s 180ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0181
# 262/262 [==============================] - 52s 197ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0186
# 262/262 [==============================] - 52s 197ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0167
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      16     a = file.read()
#      17 with open(kac_epoch, 'w') as file:
# ---> 18     a += 1
#      19     file.write(f"{a}")
#      20 break
#
# TypeError: can only concatenate str (not "int") to str

# %%
gc.collect()
with open('C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\devam_indisi.txt', 'r') as file:
    st_ix = int(file.read())

# %%
X_val.shape

# %%
X_val, y_val, _ = data_generator(start_index=464,batch_size=50)

pred_loss = 0
x_loss = 0
pred_batch = 100
last = 1000
for i in range(0, last, pred_batch):
    predictions = Model.predict(X_val[i:i + pred_batch])
    predictions[predictions < 0.0] = 0.0
    predictions[predictions > 1.0] = 1.0
    pred_loss += np.sum(np.square(predictions[0:pred_batch] - y_val[i:i + pred_batch])) 
    x_loss += np.sum(np.square(X_val[i:i + pred_batch] - y_val[i:i + pred_batch])) 

pred_loss = pred_loss / last
x_loss = x_loss / last
# Out:
# 4/4 [==============================] - 4s 305ms/step
# 4/4 [==============================] - 1s 318ms/step
# 4/4 [==============================] - 1s 316ms/step
# 4/4 [==============================] - 1s 318ms/step
# 4/4 [==============================] - 1s 317ms/step
# 4/4 [==============================] - 1s 318ms/step
# 4/4 [==============================] - 1s 321ms/step
# 4/4 [==============================] - 1s 318ms/step
# 4/4 [==============================] - 1s 319ms/step
# 4/4 [==============================] - 1s 319ms/step

# %%
print(f"pred loss: {pred_loss}")
print(f"x_loss: {x_loss}")
# Out:
# pred loss: 86.94172260212787
# x_loss: 90.16467984621299

# %%
idx = 0
cv2.imwrite("C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\gorseller\\X.png", X_val[99] * 255.0)
cv2.imwrite("C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\gorseller\\pred.png", predictions[9] * 255.0)
cv2.imwrite("C:\\Users\\Furkan\\Desktop\\BLG4901E\\CNN\\gorseller\\y.png", y_val[99] * 255.0)
